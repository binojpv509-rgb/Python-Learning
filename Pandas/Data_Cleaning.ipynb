# %%
import pandas as pd

sales_2017 = pd.read_csv('Sales Transactions-2017.csv')
sales_2018 = pd.read_csv('Sales Transactions-2018.csv')
sales_2019 = pd.read_csv('Sales Transactions-2019.csv')

# %%
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
data_ls = [sales_2017, sales_2018, sales_2019]

# %%
sales_data_df = pd.concat(data_ls)

# %%
sales_data_df
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_data_df.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
sales_data_df = sales_data_df.dropna(subset='Qty')

# %%
sales_data_df.isna().sum()
# Out:
# Date                 34
# Voucher               0
# Party                34
# Product              34
# Qty                   0
# Rate                  1
# Gross                 1
# Disc              93052
# Voucher Amount    71089
# dtype: int64

# %%
sales_data_df = sales_data_df.dropna(subset='Date')

# %%
sales_data_df.isna().sum()
# Out:
# Date                  0
# Voucher               0
# Party                 0
# Product               0
# Qty                   0
# Rate                  1
# Gross                 1
# Disc              93052
# Voucher Amount    71089
# dtype: int64

# %%
del sales_data_df['Voucher Amount']

# %%
sales_data_df.isna().sum()
# Out:
# Date           0
# Voucher        0
# Party          0
# Product        0
# Qty            0
# Rate           1
# Gross          1
# Disc       93052
# dtype: int64

# %%
sales_data_df['Disc'] = sales_data_df['Disc'].fillna(0)

# %%
sales_data_df.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# Gross      1
# Disc       0
# dtype: int64

# %%
sales_data_df.shape
# Out:
# (98615, 8)

# %%
sales_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98615 entries, 0 to 19171
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     98615 non-null  object
#  1   Voucher  98615 non-null  object
#  2   Party    98615 non-null  object
#  3   Product  98615 non-null  object
#  4   Qty      98615 non-null  object
#  5   Rate     98614 non-null  object
#  6   Gross    98614 non-null  object
#  7   Disc     98615 non-null  object
# dtypes: object(8)
# memory usage: 6.8+ MB

# %%
sales_data_df['Date'] = pd.to_datetime(sales_data_df['Date'], errors='coerce', format = "%d/%m/%Y")

# %%
sales_data_df = sales_data_df.dropna(subset='Date')

# %%
(sales_data_df == ' ').sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       0
# Gross      0
# Disc       0
# dtype: int64

# %%
sales_data_df['Disc'] = sales_data_df['Disc'].replace(' ', '')

# %%
sales_data_df['Disc'] = sales_data_df['Disc'].replace(',', '', regex = True)

# %%
sales_data_df['Disc'] = pd.to_numeric(sales_data_df['Disc'])

# %%
sales_data_df.dtypes
# Out:
# Date       datetime64[ns]
# Voucher            object
# Party              object
# Product            object
# Qty               float64
# Rate              float64
# Gross             float64
# Disc              float64
# dtype: object

# %%
sales_data_df['Qty'] = sales_data_df['Qty'].replace(' ', '')

# %%
sales_data_df['Qty'] = sales_data_df['Qty'].replace(',', '', regex = True)

# %%
sales_data_df['Qty'] = pd.to_numeric(sales_data_df['Qty'])

# %%
sales_data_df
# Out:
#             Date   Voucher               Party              Product    Qty  \
# 0     2017-04-01     Sal:1    SOLANKI PLASTICS        DONA-VAI-9100    2.0
# 1     2017-04-01     Sal:1    SOLANKI PLASTICS      LITE FOAM(1200)    6.0
# 2     2017-04-01     Sal:2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500.0
# 3     2017-04-01     Sal:2  SARNESWARA TRADERS      LITE FOAM(1200)    6.0
# 4     2017-04-01     Sal:2  SARNESWARA TRADERS        DONA-VAI-9100    5.0
# ...          ...       ...                 ...                  ...    ...
# 19167 2019-10-10  Sal:4935           K.SRIHARI         16*20(100-W)  140.0
# 19168 2019-10-10  Sal:4935           K.SRIHARI  10*12 KRISHNA-BK(10  600.0
# 19169 2019-10-10  Sal:4935           K.SRIHARI  13*16 Bk(100)KRISHN  320.0
# 19170 2019-10-10  Sal:4935           K.SRIHARI             10*12 RK  800.0
# 19171 2019-10-10  Sal:4935           K.SRIHARI       13*16 WHITE RK  400.0
#
#            Rate      Gross  Disc
# 0      1,690.00   3,380.00   0.0
# ...

# %%
sales_data_df['Rate'] = sales_data_df['Rate'].replace(',', '', regex = True)

# %%
sales_data_df['Rate'] = pd.to_numeric(sales_data_df['Rate'])

# %%
sales_data_df['Gross'] = sales_data_df['Gross'].replace(',', '', regex = True)

# %%
sales_data_df['Gross'] = pd.to_numeric(sales_data_df['Gross'])
